# %% [markdown]
# The ground Hatree-Fock state is when 1up and 1down orbitals (molecular orbitals) are occupied. This is (1, 1, 0, 0) in fermion occupation basis. In Bravyi-Kitaev basis, this is (1, 0, 0, 0), so just X(0).

# %%
from openfermion.ops import FermionOperator
from openfermion.transforms import jordan_wigner, bravyi_kitaev
from openfermion.utils import hermitian_conjugated
from openfermion.utils import uccsd_generator
import numpy as np

from pyquil.paulis import PauliSum
from pyquil.api import WavefunctionSimulator
from scipy.optimize import minimize
from pyquil import Program
from pyquil.gates import *

from openfermion.ops import QubitOperator
from forestopenfermion import pyquilpauli_to_qubitop, qubitop_to_pyquilpauli
from forestopenfermion import exponentiate

import numpy as np
import functools

from openfermion.hamiltonians import MolecularData, load_molecular_hamiltonian

# %%
from pyquil import get_qc
qc = get_qc('4q-qvm')

# %%
numQubit = 4
trials = 100
class Track:
    def __init__(self):
        self.cnt = 0
        
def build_ansatz(params):
    # Reference state
    a = None
    a = Program()

    single_amp = []
    double_amp = []

    # occupied: 0,1 unoccupied: 2,3
    single_amp.append([[2,0], params[0]])
    single_amp.append([[3,1], params[1]])

    if degree == 2:
        double_amp.append([[2,0,3,1], params[2]])

    ucc_gen = uccsd_generator(single_amp, double_amp)
    ucc_gen_qubitop = bravyi_kitaev(ucc_gen)
    try:
        ucc_program = exponentiate(ucc_gen_qubitop/(-1j))
    except:
        ucc_program = I(0)
    a += ucc_program
    return a

def solve_vqe_ucc_h2(hamiltonian: PauliSum, numLayer) -> float:
    # Construct a variational quantum eigensolver solution to find the lowest
    # eigenvalue of the given hamiltonian
    
    numParams = 0
    if degree == 1:
        numParams = 2
    elif degree == 2:
        numParams = 3
    params_init = np.random.rand(numParams)*0.5-0.25
    #params_init = [7.25536731e-07,  1.04666900e-06, -1.04874604e-01]
    
    track = Track()

    def inc(t, xk):
        t.cnt += 1

    def ansatz_energy(t, params):
        t.cnt += 1
        energy = 0
        ansatz = None
        ansatz = Program()
        ansatz += build_ansatz(params)
        
        energy = 0
        for term in hamiltonian:
            p = None
            p = Program()
            p += X(0)
            p += ansatz

            coeff = term.coefficient.real    # coefficient is real number in complex format
            opset =  term.operations_as_set()
            qubits_meas = []
            for op in opset:
                if op[1]=='X':
                    p += H(op[0])
                elif op[1]=='Y':
                    p += RZ(np.pi/2, op[0])
                    p += RY(np.pi/2, op[0])
                    p += RZ(-np.pi/2, op[0])
                elif op[1]=='Z':
                    pass
                qubits_meas.append(op[0])
  
            result = qc.run_and_measure(p, trials=trials)
            # measure the expectation value of eigenvalue in Z..Z basis. (number of 1 - number of -1)/trials
            eigval = 0
            for i in range(trials):
                tmp = 1
                for j in qubits_meas:
                    if result[j][i] == 1:
                        tmp = -tmp
                eigval += tmp
            energy += coeff*float(eigval)/trials
            
        print(energy)
        return energy

    option = {}
    option['ftol'] = 0.1
    params_answer = minimize(functools.partial(ansatz_energy, track), params_init, method='L-BFGS-B', options = option).x
    return ansatz_energy(track, params_answer), track.cnt

# %%
def get_ground_energy_ucc_h2(interaction_hamil, degree):
    fermionop_hamil = FermionOperator()
    for key in interaction_hamil:
        value = interaction_hamil[key]
        fermionop_hamil += FermionOperator(term=key, coefficient=value)
        
    qubitop_hamil = bravyi_kitaev(fermionop_hamil)
    pauliop_hamil = qubitop_to_pyquilpauli(qubitop_hamil)

    return solve_vqe_ucc_h2(pauliop_hamil, degree)

# %%
basis = 'sto-3g'
multiplicity = 1  # 2S+1
charge = 0

import matplotlib.pyplot as plt
# %matplotlib inline

bond_lengths = [0.7] #np.linspace(0.3, 2.5, 23)
vqe_ground_energies_mean = []
vqe_ground_energies_std = []
vqe_iter_mean = []
vqe_iter_std = []

for degree in [2]:
    gelist = []
    gestdlist = []
    iterlist = []
    iterstdlist = []
    for bond_length in bond_lengths:
        geometry = [('H', (0., 0., 0.)), ('H', (0., 0., bond_length))]
        description = str(round(bond_length, 2))
        h2_interaction_hamil = load_molecular_hamiltonian(geometry,
            basis,
            multiplicity,
            description,
            n_active_electrons=None,
            n_active_orbitals=None)

        gelist_temp = []
        iterlist_temp = []
        for i in range(1):
            ge, cnt = get_ground_energy_ucc_h2(h2_interaction_hamil, degree)
            print('bond length: ', round(bond_length, 2), ' ground state energy: ', ge, ' iteration: ', cnt)
            gelist_temp.append(ge)
            iterlist_temp.append(cnt)
        gelist.append(np.mean(gelist_temp))
        gestdlist.append(np.std(gelist_temp))
        iterlist.append(np.mean(iterlist_temp))
        iterstdlist.append(np.std(iterlist_temp))
        
    vqe_ground_energies_mean.append(gelist)
    vqe_ground_energies_std.append(gestdlist)
    vqe_iter_mean.append(np.mean(iterlist))
    vqe_iter_std.append(np.mean(iterstdlist))
# Out:
# -0.9356876192211276
# -0.9457248825067837
# -0.9093537141973433
# -0.947286630719343
# -0.6328947900332489
# -0.615014298789383
# -0.6017888929011674
# -0.6232776128975063
# -0.8223994780558295
# -0.8295085719934328
# -0.8540722214624559
# -0.8278551266057502
# -0.8916087120392671
# -0.8977721314768607
# -0.8778298848222745
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-62b24f79ade0> in <module>()
#      30         iterlist_temp = []
#      31         for i in range(1):
# ---> 32             ge, cnt = get_ground_energy_ucc_h2(h2_interaction_hamil, degree)
#      33             print('bond length: ', round(bond_length, 2), ' ground state energy: ', ge, ' iteration: ', cnt)
#      34             gelist_temp.append(ge)
#
# <ipython-input-4-24167dee6ab6> in get_ground_energy_ucc_h2(interaction_hamil, degree)
#       8     pauliop_hamil = qubitop_to_pyquilpauli(qubitop_hamil)
#       9
# ---> 10     return solve_vqe_ucc_h2(pauliop_hamil, degree)
#
# <ipython-input-3-f9888ab560e9> in solve_vqe_ucc_h2(hamiltonian, numLayer)
#      90     option = {}
#      91     option['ftol'] = 0.1
# ---> 92     params_answer = minimize(functools.partial(ansatz_energy, track), params_init, method='L-BFGS-B', options = option).x
#      93     return ansatz_energy(track, params_answer), track.cnt
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     601     elif meth == 'l-bfgs-b':
#     602         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 603                                 callback=callback, **options)
#     604     elif meth == 'tnc':
#     605         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     333             # until the completion of the current minimization iteration.
#     334             # Overwrite f and g:
# --> 335             f, g = func_and_grad(x)
#     336         elif task_str.startswith(b'NEW_X'):
#     337             # new iteration
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py in func_and_grad(x)
#     279         def func_and_grad(x):
#     280             f = fun(x, *args)
# --> 281             g = _approx_fprime_helper(x, fun, epsilon, args=args, f0=f)
#     282             return f, g
#     283     else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in _approx_fprime_helper(xk, f, epsilon, args, f0)
#     661         ei[k] = 1.0
#     662         d = epsilon * ei
# --> 663         grad[k] = (f(*((xk + d,) + args)) - f0) / d[k]
#     664         ei[k] = 0.0
#     665     return grad
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     291     def function_wrapper(*wrapper_args):
#     292         ncalls[0] += 1
# --> 293         return function(*(wrapper_args + args))
#     294
#     295     return ncalls, function_wrapper
#
# <ipython-input-3-f9888ab560e9> in ansatz_energy(t, params)
#      74                 qubits_meas.append(op[0])
#      75
# ---> 76             result = qc.run_and_measure(p, trials=trials)
#      77             # measure the expectation value of eigenvalue in Z..Z basis. (number of 1 - number of -1)/trials
#      78             eigval = 0
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyquil\api\_error_reporting.py in wrapper(*args, **kwargs)
#     236             global_error_context.log[key] = pre_entry
#     237
# --> 238         val = func(*args, **kwargs)
#     239
#     240         # poke the return value of that call in
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyquil\api\_quantum_computer.py in run_and_measure(self, program, trials)
#     225         program.wrap_in_numshots_loop(trials)
#     226         executable = self.compile(program)
# --> 227         bitstring_array = self.run(executable=executable)
#     228         bitstring_dict = {}
#     229         for i, q in enumerate(self.qubits()):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyquil\api\_error_reporting.py in wrapper(*args, **kwargs)
#     236             global_error_context.log[key] = pre_entry
#     237
# --> 238         val = func(*args, **kwargs)
#     239
#     240         # poke the return value of that call in
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyquil\api\_quantum_computer.py in run(self, executable, memory_map)
#     144         :return: A numpy array of shape (trials, len(ro-register)) that contains 0s and 1s.
#     145         """
# --> 146         self.qam.load(executable)
#     147         if memory_map:
#     148             for region_name, values_list in memory_map.items():
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyquil\api\_error_reporting.py in wrapper(*args, **kwargs)
#     236             global_error_context.log[key] = pre_entry
#     237
# --> 238         val = func(*args, **kwargs)
#     239
#     240         # poke the return value of that call in
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyquil\api\_qvm.py in load(self, executable)
#     440         else:
#     441             if isinstance(executable, PyQuilExecutableResponse):
# --> 442                 executable = _extract_program_from_pyquil_executable_response(executable)
#     443             elif isinstance(executable, Program):
#     444                 pass
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyquil\api\_compiler.py in _extract_program_from_pyquil_executable_response(response)
#      60     :return: Resulting pyQuil Program object.
#      61     """
# ---> 62     p = Program(response.program)
#      63     for attr, val in response.attributes.items():
#      64         setattr(p, attr, val)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyquil\quil.py in __init__(self, *instructions)
#      62         self._synthesized_instructions = None
#      63
# ---> 64         self.inst(*instructions)
#      65
#      66         # Filled in with quil_to_native_quil
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyquil\quil.py in inst(self, *instructions)
#     166                         self.gate(op, params, rest)
#     167             elif isinstance(instruction, string_types):
# --> 168                 self.inst(run_parser(instruction.strip()))
#     169             elif isinstance(instruction, Program):
#     170                 if id(self) == id(instruction):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyquil\_parser\PyQuilListener.py in run_parser(quil)
#      65     parser.removeErrorListeners()
#      66     parser.addErrorListener(CustomErrorListener())
# ---> 67     tree = parser.quil()
#      68
#      69     # Step 3: Run the Listener
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyquil\_parser\gen3\QuilParser.py in quil(self)
#     481
#     482                     self.state = 110
# --> 483                     self.allInstr()
#     484                 self.state = 115
#     485                 self._errHandler.sync(self)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyquil\_parser\gen3\QuilParser.py in allInstr(self)
#     559                 self.enterOuterAlt(localctx, 3)
#     560                 self.state = 126
# --> 561                 self.instr()
#     562                 pass
#     563             else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyquil\_parser\gen3\QuilParser.py in instr(self)
#     675                 self.enterOuterAlt(localctx, 1)
#     676                 self.state = 129
# --> 677                 self.gate()
#     678                 pass
#     679             elif token in [QuilParser.MEASURE]:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyquil\_parser\gen3\QuilParser.py in gate(self)
#     839                 self.match(QuilParser.LPAREN)
#     840                 self.state = 151
# --> 841                 self.param()
#     842                 self.state = 156
#     843                 self._errHandler.sync(self)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyquil\_parser\gen3\QuilParser.py in param(self)
#     985             self.enterOuterAlt(localctx, 1)
#     986             self.state = 172
# --> 987             self.expression(0)
#     988         except RecognitionException as re:
#     989             localctx.exception = re
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyquil\_parser\gen3\QuilParser.py in expression(self, _p)
#    3689                     self.state = 453
#    3690                     self._errHandler.sync(self)
# -> 3691                     la_ = self._interp.adaptivePredict(self._input,40,self._ctx)
#    3692                     if la_ == 1:
#    3693                         localctx = QuilParser.PowerExpContext(self, QuilParser.ExpressionContext(self, _parentctx, _parentState))
#
# C:\ProgramData\Anaconda3\lib\site-packages\antlr4\atn\ParserATNSimulator.py in adaptivePredict(self, input, decision, outerContext)
#     340                     dfa.s0 = s0
#     341
# --> 342             alt = self.execATN(dfa, s0, input, index, outerContext)
#     343             if ParserATNSimulator.debug:
#     344                 print("DFA after predictATN: " + dfa.toString(self.parser.literalNames))
#
# C:\ProgramData\Anaconda3\lib\site-packages\antlr4\atn\ParserATNSimulator.py in execATN(self, dfa, s0, input, startIndex, outerContext)
#     448
#     449                 stopIndex = input.index
# --> 450                 input.seek(startIndex)
#     451                 alts = self.evalSemanticContext(D.predicates, outerContext, True)
#     452                 if len(alts)==0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\antlr4\BufferedTokenStream.py in seek(self, index)
#      73
#      74     def seek(self, index:int):
# ---> 75         self.lazyInit()
#      76         self.index = self.adjustSeekIndex(index)
#      77
#
# KeyboardInterrupt:
