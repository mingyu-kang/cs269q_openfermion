# %% [markdown]
# The ground Hatree-Fock state is when 1up and 1down orbitals (molecular orbitals) are occupied. This is (1, 1, 0, 0) in fermion occupation basis. In Bravyi-Kitaev basis, this is (1, 0, 0, 0), so just X(0).

# %%
from openfermion.ops import FermionOperator
from openfermion.transforms import jordan_wigner, bravyi_kitaev
from openfermion.utils import hermitian_conjugated
from openfermion.utils import uccsd_generator
import numpy as np

from pyquil.paulis import PauliSum
from pyquil.api import WavefunctionSimulator
from scipy.optimize import minimize
from pyquil import Program
from pyquil.gates import *

from openfermion.ops import QubitOperator
from forestopenfermion import pyquilpauli_to_qubitop, qubitop_to_pyquilpauli
from forestopenfermion import exponentiate

import numpy as np
import functools

from openfermion.hamiltonians import MolecularData, load_molecular_hamiltonian

# %%
sim = WavefunctionSimulator()
numQubit = 4
class Track:
    def __init__(self):
        self.cnt = 0


def solve_vqe_ucc_h2(hamiltonian: PauliSum, degree) -> float:
    # Construct a variational quantum eigensolver solution to find the lowest
    # eigenvalue of the given hamiltonian
    
    # degree 1: up to T_1
    # degree 2: up to T_2
    
    numParams = 0
    if degree == 1:
        numParams = 2
    elif degree == 2:
        numParams = 3
    params_init = np.random.rand(numParams)*0.5-0.25
    
    track = Track()

    def inc(t, xk):
        t.cnt += 1
    
    def ansatz_energy(t, params):
        t.cnt += 1
        p = None
        p = Program()
        
        # Reference state
        p += X(0)
        
        single_amp = []
        double_amp = []
        
        # occupied: 0,1 unoccupied: 2,3
        single_amp.append([[2,0], params[0]])
        single_amp.append([[3,1], params[1]])
        
        if degree >= 2:
            double_amp.append([[2,0,3,1], params[2]])
        
        ucc_gen = uccsd_generator(single_amp, double_amp)
        ucc_gen_qubitop = bravyi_kitaev(ucc_gen)
        try:
            ucc_program = exponentiate(ucc_gen_qubitop/(-1j))
        except:
            ucc_program = I(0)
        p += ucc_program

        energy = sim.expectation(p, hamiltonian).real
        return energy

    params_answer = minimize(functools.partial(ansatz_energy, track), params_init, method='L-BFGS-B').x
    print(params_answer)
    return ansatz_energy(track, params_answer), track.cnt

# %%
def get_ground_energy_ucc_h2(interaction_hamil, degree):
    fermionop_hamil = FermionOperator()
    for key in interaction_hamil:
        value = interaction_hamil[key]
        fermionop_hamil += FermionOperator(term=key, coefficient=value)
        
    qubitop_hamil = bravyi_kitaev(fermionop_hamil)
    pauliop_hamil = qubitop_to_pyquilpauli(qubitop_hamil)
    
    sim = WavefunctionSimulator()
    return solve_vqe_ucc_h2(pauliop_hamil, degree)

# %%
basis = 'sto-3g'
multiplicity = 1  # 2S+1
charge = 0

import matplotlib.pyplot as plt
# %matplotlib inline

bond_lengths = np.linspace(0.3, 2.5, 23)
vqe_ground_energies_mean = []
vqe_ground_energies_std = []
vqe_iter_mean = []
vqe_iter_std = []

for degree in [1,2]:
    gelist = []
    gestdlist = []
    iterlist = []
    iterstdlist = []
    for bond_length in bond_lengths:
        geometry = [('H', (0., 0., 0.)), ('H', (0., 0., bond_length))]
        description = str(round(bond_length, 2))
        h2_interaction_hamil = load_molecular_hamiltonian(geometry,
            basis,
            multiplicity,
            description,
            n_active_electrons=None,
            n_active_orbitals=None)

        gelist_temp = []
        iterlist_temp = []
        for i in range(5):
            ge, cnt = get_ground_energy_ucc_h2(h2_interaction_hamil, degree)
            print('bond length: ', round(bond_length, 2), ' ground state energy: ', ge, ' iteration: ', cnt)
            gelist_temp.append(ge)
            iterlist_temp.append(cnt)
        gelist.append(np.mean(gelist_temp))
        gestdlist.append(np.std(gelist_temp))
        iterlist.append(np.mean(iterlist_temp))
        iterstdlist.append(np.std(iterlist_temp))
        
    vqe_ground_energies_mean.append(gelist)
    vqe_ground_energies_std.append(gestdlist)
    vqe_iter_mean.append(np.mean(iterlist))
    vqe_iter_std.append(np.mean(iterstdlist))
# Out:
# bond length:  0.3  ground state energy:  -0.5938277645842471  iteration:  19
# bond length:  0.3  ground state energy:  -0.5938277645849367  iteration:  19
# bond length:  0.3  ground state energy:  -0.5938277645836805  iteration:  19
# bond length:  0.3  ground state energy:  -0.5938277645801695  iteration:  16
# bond length:  0.3  ground state energy:  -0.593827764584608  iteration:  19
# bond length:  0.4  ground state energy:  -0.9043613977137945  iteration:  19
# bond length:  0.4  ground state energy:  -0.9043613977128286  iteration:  19
# bond length:  0.4  ground state energy:  -0.9043613977138426  iteration:  19
# bond length:  0.4  ground state energy:  -0.9043613977119225  iteration:  19
# bond length:  0.4  ground state energy:  -0.9043613977138426  iteration:  19
# bond length:  0.5  ground state energy:  -1.0429962765062097  iteration:  19
# bond length:  0.5  ground state energy:  -1.042996276507171  iteration:  19
# bond length:  0.5  ground state energy:  -1.0429962765065643  iteration:  22
# bond length:  0.5  ground state energy:  -1.0429962765020442  iteration:  19
# bond length:  0.5  ground state energy:  -1.0429962764998144  iteration:  19
# bond length:  0.6  ground state energy:  -1.1011282431197287  iteration:  19
# bond length:  0.6  ground state energy:  -1.1011282431135192  iteration:  19
# bond length:  0.6  ground state energy:  -1.1011282431368197  iteration:  19
# bond length:  0.6  ground state energy:  -1.1011282431367662  iteration:  19
# bond length:  0.6  ground state energy:  -1.1011282431368126  iteration:  19
# bond length:  0.7  ground state energy:  -1.1173490350491724  iteration:  22
# bond length:  0.7  ground state energy:  -1.1173490350703141  iteration:  22
# bond length:  0.7  ground state energy:  -1.117349035067649  iteration:  22
# bond length:  0.7  ground state energy:  -1.117349035068494  iteration:  19
# bond length:  0.7  ground state energy:  -1.1173490350697668  iteration:  19
# bond length:  0.8  ground state energy:  -1.1108503969721333  iteration:  19
# bond length:  0.8  ground state energy:  -1.1108503969853787  iteration:  25
# bond length:  0.8  ground state energy:  -1.1108503969833716  iteration:  19
# bond length:  0.8  ground state energy:  -1.1108503969854135  iteration:  25
# bond length:  0.8  ground state energy:  -1.1108503969540409  iteration:  22
# bond length:  0.9  ground state energy:  -1.0919140401064726  iteration:  25
# bond length:  0.9  ground state energy:  -1.0919140401067926  iteration:  19
# bond length:  0.9  ground state energy:  -1.0919140400990446  iteration:  25
# bond length:  0.9  ground state energy:  -1.0919140401071081  iteration:  22
# bond length:  0.9  ground state energy:  -1.0919140401056986  iteration:  22
# bond length:  1.0  ground state energy:  -1.0661086480817081  iteration:  22
# bond length:  1.0  ground state energy:  -1.0661086480808126  iteration:  25
# bond length:  1.0  ground state energy:  -1.066108648081672  iteration:  25
# bond length:  1.0  ground state energy:  -1.0661086480742241  iteration:  22
# bond length:  1.0  ground state energy:  -1.0661086480675508  iteration:  25
# bond length:  1.1  ground state energy:  -1.036538873382391  iteration:  25
# bond length:  1.1  ground state energy:  -1.0365388734981456  iteration:  28
# bond length:  1.1  ground state energy:  -1.0365388733732497  iteration:  25
# bond length:  1.1  ground state energy:  -1.0365388735296324  iteration:  28
# bond length:  1.1  ground state energy:  -1.0365388734955885  iteration:  22
# bond length:  1.2  ground state energy:  -1.0063725104561123  iteration:  25
# bond length:  1.2  ground state energy:  -1.006372510457544  iteration:  40
# bond length:  1.2  ground state energy:  -1.0063725104572918  iteration:  37
# bond length:  1.2  ground state energy:  -1.0063725104577586  iteration:  43
# bond length:  1.2  ground state energy:  -1.0063725104414365  iteration:  46
# bond length:  1.3  ground state energy:  -0.9840276132828902  iteration:  43
# bond length:  1.3  ground state energy:  -0.9840276133264628  iteration:  37
# bond length:  1.3  ground state energy:  -0.9840276133299787  iteration:  31
# bond length:  1.3  ground state energy:  -0.9840276133306743  iteration:  58
# bond length:  1.3  ground state energy:  -0.9840276133290581  iteration:  31
# bond length:  1.4  ground state energy:  -0.9684912881047898  iteration:  46
# bond length:  1.4  ground state energy:  -0.9684912880958096  iteration:  46
# bond length:  1.4  ground state energy:  -0.9684912881007551  iteration:  28
# bond length:  1.4  ground state energy:  -0.9684912880896426  iteration:  40
# bond length:  1.4  ground state energy:  -0.9684912881028209  iteration:  37
# bond length:  1.5  ground state energy:  -0.9577067928155144  iteration:  40
# bond length:  1.5  ground state energy:  -0.9577067927808329  iteration:  49
# bond length:  1.5  ground state energy:  -0.9577067928096971  iteration:  28
# bond length:  1.5  ground state energy:  -0.9577067928156119  iteration:  31
# bond length:  1.5  ground state energy:  -0.9577067928155728  iteration:  46
# bond length:  1.6  ground state energy:  -0.9502279115448276  iteration:  37
# bond length:  1.6  ground state energy:  -0.9502279115449122  iteration:  49
# bond length:  1.6  ground state energy:  -0.9502279115448842  iteration:  43
# bond length:  1.6  ground state energy:  -0.9502279115422464  iteration:  52
# bond length:  1.6  ground state energy:  -0.9502279115429599  iteration:  37
# bond length:  1.7  ground state energy:  -0.9450422286609541  iteration:  37
# bond length:  1.7  ground state energy:  -0.9450422286599536  iteration:  49
# bond length:  1.7  ground state energy:  -0.9450422286583255  iteration:  43
# bond length:  1.7  ground state energy:  -0.9450422286238567  iteration:  40
# bond length:  1.7  ground state energy:  -0.9450422286571806  iteration:  55
# bond length:  1.8  ground state energy:  -0.9414451549884638  iteration:  40
# bond length:  1.8  ground state energy:  -0.9414451550003013  iteration:  40
# bond length:  1.8  ground state energy:  -0.941445154973728  iteration:  28
# bond length:  1.8  ground state energy:  -0.9414451549999845  iteration:  40
# bond length:  1.8  ground state energy:  -0.9414451550003025  iteration:  28
# bond length:  1.9  ground state energy:  -0.938948133818666  iteration:  28
# bond length:  1.9  ground state energy:  -0.9389481338308152  iteration:  43
# bond length:  1.9  ground state energy:  -0.9389481338361606  iteration:  43
# bond length:  1.9  ground state energy:  -0.9389481338381575  iteration:  31
# bond length:  1.9  ground state energy:  -0.93894813383811  iteration:  73
# bond length:  2.0  ground state energy:  -0.9372128329576132  iteration:  46
# bond length:  2.0  ground state energy:  -0.9372128329700039  iteration:  52
# bond length:  2.0  ground state energy:  -0.9372128329701065  iteration:  40
# bond length:  2.0  ground state energy:  -0.9372128329508604  iteration:  34
# bond length:  2.0  ground state energy:  -0.9372128329571269  iteration:  70
# bond length:  2.1  ground state energy:  -0.9360049738031136  iteration:  52
# bond length:  2.1  ground state energy:  -0.936004973809023  iteration:  52
# bond length:  2.1  ground state energy:  -0.9360049738131978  iteration:  52
# bond length:  2.1  ground state energy:  -0.9360049738350827  iteration:  40
# bond length:  2.1  ground state energy:  -0.9360049738347147  iteration:  49
# bond length:  2.2  ground state energy:  -0.9351623642633691  iteration:  28
# bond length:  2.2  ground state energy:  -0.935162364267085  iteration:  49
# bond length:  2.2  ground state energy:  -0.935162364267084  iteration:  55
# bond length:  2.2  ground state energy:  -0.9351623642428852  iteration:  34
# bond length:  2.2  ground state energy:  -0.9351623642670498  iteration:  85
# bond length:  2.3  ground state energy:  -0.9345728285578564  iteration:  31
# bond length:  2.3  ground state energy:  -0.9345728285580613  iteration:  52
# bond length:  2.3  ground state energy:  -0.9345728285493207  iteration:  31
# bond length:  2.3  ground state energy:  -0.9345728285441781  iteration:  55
# bond length:  2.3  ground state energy:  -0.9345728285463563  iteration:  25
# bond length:  2.4  ground state energy:  -0.9341589091991626  iteration:  43
# bond length:  2.4  ground state energy:  -0.9341589091889391  iteration:  28
# bond length:  2.4  ground state energy:  -0.9341589091989075  iteration:  31
# bond length:  2.4  ground state energy:  -0.9341589091991922  iteration:  46
# bond length:  2.4  ground state energy:  -0.9341589091991906  iteration:  64
# bond length:  2.5  ground state energy:  -0.9338672030751783  iteration:  64
# bond length:  2.5  ground state energy:  -0.9338672031060604  iteration:  31
# bond length:  2.5  ground state energy:  -0.9338672031018826  iteration:  49
# bond length:  2.5  ground state energy:  -0.9338672030974159  iteration:  43
# bond length:  2.5  ground state energy:  -0.9338672031060461  iteration:  43
# bond length:  0.3  ground state energy:  -0.601803716834987  iteration:  33
# bond length:  0.3  ground state energy:  -0.6018037168346342  iteration:  33
# bond length:  0.3  ground state energy:  -0.6018037168347123  iteration:  33
# bond length:  0.3  ground state energy:  -0.601803716835108  iteration:  33
# bond length:  0.3  ground state energy:  -0.6018037168192347  iteration:  33
# bond length:  0.4  ground state energy:  -0.9141497082133062  iteration:  33
# bond length:  0.4  ground state energy:  -0.9141497082133422  iteration:  33
# bond length:  0.4  ground state energy:  -0.9141497081993051  iteration:  33
# bond length:  0.4  ground state energy:  -0.9141497082141264  iteration:  37
# bond length:  0.4  ground state energy:  -0.9141497082011791  iteration:  33
# bond length:  0.5  ground state energy:  -1.055159796496585  iteration:  33
# bond length:  0.5  ground state energy:  -1.0551597964966117  iteration:  33
# bond length:  0.5  ground state energy:  -1.0551597964895065  iteration:  33
# bond length:  0.5  ground state energy:  -1.05515979649645  iteration:  37
# bond length:  0.5  ground state energy:  -1.0551597964888089  iteration:  33
# bond length:  0.6  ground state energy:  -1.1162860078230175  iteration:  33
# bond length:  0.6  ground state energy:  -1.1162860078264187  iteration:  37
# bond length:  0.6  ground state energy:  -1.1162860078211259  iteration:  33
# bond length:  0.6  ground state energy:  -1.11628600782648  iteration:  29
# bond length:  0.6  ground state energy:  -1.116286007826495  iteration:  37
# bond length:  0.7  ground state energy:  -1.1361894542707835  iteration:  33
# bond length:  0.7  ground state energy:  -1.136189454269297  iteration:  37
# bond length:  0.7  ground state energy:  -1.1361894542669329  iteration:  33
# bond length:  0.7  ground state energy:  -1.1361894542699453  iteration:  29
# bond length:  0.7  ground state energy:  -1.1361894542700974  iteration:  33
# bond length:  0.8  ground state energy:  -1.1341476663578023  iteration:  37
# bond length:  0.8  ground state energy:  -1.1341476663559604  iteration:  33
# bond length:  0.8  ground state energy:  -1.134147666357697  iteration:  33
# bond length:  0.8  ground state energy:  -1.1341476663578467  iteration:  37
# bond length:  0.8  ground state energy:  -1.1341476663562744  iteration:  33
# bond length:  0.9  ground state energy:  -1.1205602806180142  iteration:  37
# bond length:  0.9  ground state energy:  -1.1205602806185508  iteration:  33
# bond length:  0.9  ground state energy:  -1.1205602806185477  iteration:  33
# bond length:  0.9  ground state energy:  -1.1205602806140214  iteration:  37
# bond length:  0.9  ground state energy:  -1.1205602806179535  iteration:  33
# bond length:  1.0  ground state energy:  -1.1011503292943923  iteration:  33
# bond length:  1.0  ground state energy:  -1.10115032928408  iteration:  37
# bond length:  1.0  ground state energy:  -1.1011503293035485  iteration:  41
# bond length:  1.0  ground state energy:  -1.1011503293001697  iteration:  37
# bond length:  1.0  ground state energy:  -1.1011503292815332  iteration:  41
# bond length:  1.1  ground state energy:  -1.079192943879902  iteration:  37
# bond length:  1.1  ground state energy:  -1.079192943867314  iteration:  33
# bond length:  1.1  ground state energy:  -1.079192943879301  iteration:  33
# bond length:  1.1  ground state energy:  -1.0791929438794932  iteration:  33
# bond length:  1.1  ground state energy:  -1.0791929438793513  iteration:  37
# bond length:  1.2  ground state energy:  -1.0567407451292692  iteration:  33
# bond length:  1.2  ground state energy:  -1.0567407451325643  iteration:  37
# bond length:  1.2  ground state energy:  -1.0567407451298123  iteration:  33
# bond length:  1.2  ground state energy:  -1.056740745132511  iteration:  41
# bond length:  1.2  ground state energy:  -1.0567407451323445  iteration:  33
# bond length:  1.3  ground state energy:  -1.0351862652417658  iteration:  45
# bond length:  2.2  ground state energy:  -0.9412240334325707  iteration:  57
# bond length:  2.2  ground state energy:  -0.9412240333928913  iteration:  77
# bond length:  2.2  ground state energy:  -0.9412240333978703  iteration:  57
# bond length:  2.2  ground state energy:  -0.9412240334319532  iteration:  57
# bond length:  2.2  ground state energy:  -0.941224033433025  iteration:  61
# bond length:  2.3  ground state energy:  -0.9389223857827625  iteration:  69
# bond length:  2.3  ground state energy:  -0.9389223857576516  iteration:  49
# bond length:  2.3  ground state energy:  -0.9389223856797538  iteration:  61
# bond length:  2.3  ground state energy:  -0.9389223857894856  iteration:  53
# bond length:  2.3  ground state energy:  -0.9389223845881581  iteration:  69
# bond length:  2.4  ground state energy:  -0.9372549528193577  iteration:  29
# bond length:  2.4  ground state energy:  -0.937254952385785  iteration:  57
# bond length:  2.4  ground state energy:  -0.9372549522816698  iteration:  53
# bond length:  2.4  ground state energy:  -0.9372549528575744  iteration:  93
# bond length:  2.4  ground state energy:  -0.9372549527906474  iteration:  49
# bond length:  2.5  ground state energy:  -0.9360549198436012  iteration:  81
# bond length:  2.5  ground state energy:  -0.9360549197267327  iteration:  57
# bond length:  2.5  ground state energy:  -0.9360549198350127  iteration:  73
# bond length:  2.5  ground state energy:  -0.9360549198407015  iteration:  81
# bond length:  2.5  ground state energy:  -0.9360549198031153  iteration:  73

# %%
# Set molecule parameters.
basis = 'sto-3g'
multiplicity = 1

# Generate molecule at different bond lengths.
hf_energies = []
fci_energies = []
bond_lengths = []
for bond_length in np.linspace(0.3, 2.5, 23):
    bond_lengths += [bond_length]
    description = str(round(bond_length,2))
#    print(description)
    geometry = [('H', (0., 0., 0.)), ('H', (0., 0., bond_length))]
    molecule = MolecularData(
        geometry, basis, multiplicity, description=description)
    
    # Load data.
    molecule.load()
    fci_energies += [molecule.fci_energy]

plt.figure(0)
plt.plot(bond_lengths, vqe_ground_energies_mean[0], 'go-', linewidth=1, markersize=1, label='degree=1')
plt.plot(bond_lengths, vqe_ground_energies_mean[1], 'bo-', linewidth=1, markersize=1, label='degree=2')
plt.plot(bond_lengths, fci_energies, 'r-', linewidth=1, markersize=1, label='exact solution')
plt.legend()
plt.ylabel('Ground state energy in Hartree')
plt.xlabel('Atomic distance in Angstrom')
plt.savefig('PLOT3.pdf', bbox_inches='tight')
plt.show()

# %%
numGates = np.array([34+36, 106+36])
#plt.plot([1,2], np.array(vqe_iter_mean)*numGates, 'o-')
plt.errorbar([1,2], np.array(vqe_iter_mean)*numGates, np.array(vqe_iter_std)*numGates/np.sqrt(23))
plt.ylabel('Number of iterations')
plt.xlabel('Degree')
plt.show()
print(vqe_iter_mean)
print(vqe_iter_std/np.sqrt(23))

print(np.array(vqe_iter_mean)*numGates)
print(np.array(vqe_iter_std)*numGates/np.sqrt(23))
# Out:
# [34.313043478260866, 43.85217391304349]
# [1.37581119 0.97010635]
# [2401.91304348 6227.00869565]
# [ 96.30678334 137.75510214]

# %%
print(max(max(vqe_ground_energies_std)))

# %%
accuracy = []
for i in range(2):
    acc = 1-np.mean(np.array(vqe_ground_energies_mean[i])-np.array(fci_energies))
    accuracy.append(acc)
print(accuracy)
plt.plot([1,2], accuracy, 'o-')
plt.ylabel('Accuracy')
plt.xlabel('Number of layers')
plt.show()
# Out:
# [0.9776784174213188, 0.9999999999566576]

# %%
basis = 'sto-3g'
multiplicity = 1  # 2S+1
charge = 0

import matplotlib.pyplot as plt
# %matplotlib inline

bond_lengths = [0.7] # np.linspace(0.3, 2.5, 23)
vqe_ground_energies_mean = []
vqe_ground_energies_std = []
vqe_iter_mean = []
vqe_iter_std = []

for degree in [2]:
    gelist = []
    gestdlist = []
    iterlist = []
    iterstdlist = []
    for bond_length in bond_lengths:
        geometry = [('H', (0., 0., 0.)), ('H', (0., 0., bond_length))]
        description = str(round(bond_length, 2))
        h2_interaction_hamil = load_molecular_hamiltonian(geometry,
            basis,
            multiplicity,
            description,
            n_active_electrons=None,
            n_active_orbitals=None)

        gelist_temp = []
        iterlist_temp = []
        for i in range(5):
            ge, cnt = get_ground_energy_ucc_h2(h2_interaction_hamil, degree)
            print('bond length: ', round(bond_length, 2), ' ground state energy: ', ge, ' iteration: ', cnt)
            gelist_temp.append(ge)
            iterlist_temp.append(cnt)
        gelist.append(np.mean(gelist_temp))
        gestdlist.append(np.std(gelist_temp))
        iterlist.append(np.mean(iterlist_temp))
        iterstdlist.append(np.std(iterlist_temp))
        
    vqe_ground_energies_mean.append(gelist)
    vqe_ground_energies_std.append(gestdlist)
    vqe_iter_mean.append(np.mean(iterlist))
    vqe_iter_std.append(np.mean(iterstdlist))
# Out:
# -1.0984724394509167
# -1.0984724364140568
# -1.0984724386292875
# -1.098472441467171
# -0.4482458865949708
# -0.44824589216177935
# -0.44824589614901317
# -0.44824587621555
# -1.1312280125609886
# -1.1312280112861666
# -1.13122801217716
# -1.1312280123660592
# -1.1357678653678431
# -1.135767865564359
# -1.1357678657083372
# -1.1357678654944172
# -1.1361754054906101
# -1.136175405476833
# -1.1361754055532796
# -1.1361754054917594
# -1.1361889830786973
# -1.136188983069319
# -1.136188983084837
# -1.1361889830780405
# -1.1361894538752164
# -1.1361894538751613
# -1.1361894538752086
# -1.1361894538746995
# -1.1361894541772024
# -1.1361894541771873
# -1.1361894541771824
# -1.1361894541774555
# [ 7.25536731e-07  1.04666900e-06 -1.04874604e-01]
# -1.1361894541772024
# bond length:  0.7  ground state energy:  -1.1361894541772024  iteration:  33
# -1.0266100402173781
# -1.0266100398194786
# -1.0266100406589842
# -1.0266100327793413
# -0.33322534214931604
# -0.3332253411277741
# -0.333225343224048
# -0.3332253591231847
# -1.1173819259966362
# -1.1173819245962935
# -1.1173819274061243
# -1.1173819252574604
# -1.1296996303887195
# -1.129699629462837
# -1.1296996313149863
# -1.1296996307810985
# -1.1357564575186079
# -1.1357564574762204
# -1.135756457557009
# -1.1357564580569768
# -1.1361850300729066
# -1.136185030053443
# -1.1361850300913576
# -1.1361850301071517
# -1.1361894537955013
